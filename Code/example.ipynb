# %%
from preprocess import LazyData

# %%
data = LazyData('../Dataset/Raw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg')

# %%
data()
# Out:
# Loading data from ../Dataset/Raw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg
# ...
